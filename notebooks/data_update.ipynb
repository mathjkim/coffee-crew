# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("../data/coffee-location.csv")

# %%
df.sample(10)
# Out:
#       Unnamed: 0                       Country  Year  Production      Exports  \
# 762          762                   Philippines  1996    889.8190    27.032000
# 2275        2275                       Croatia  2015         NaN          NaN
# 2216        2216            Belgium/Luxembourg  2016         NaN          NaN
# 1308        1308                     Guatemala  2008   3784.9658  3777.590202
# 379          379                    Madagascar  2014    501.4544   137.809592
# 447          447              Papua New Guinea  2003   1154.9440  1147.168000
# 2475        2475                       Germany  2005         NaN          NaN
# 1468        1468                         India  2019   4987.6264  6027.861152
# 1294        1294                     Guatemala  1994   3787.3360  3274.069000
# 1116        1116  Democratic Republic of Congo  2008    421.9583   203.203617
#
#       Domestic_consumption  Gross_opening_stocks       Imports   Re_exports  \
# ...

# %%
df['Imports (tonnes)'] = df.Imports*60
df['Consumption (tonnes)'] = df.Consumption*60
df['Re_exports (tonnes)'] = df.Re_exports*60

# %%
df.sample(10)
# Out:
#       Unnamed: 0                           Country  Year  Production  \
# 1802        1802                         Sri Lanka  2006     32.8750
# 1260        1260                             Ghana  1990     37.8550
# 1188        1188                 Equatorial Guinea  2008      0.0000
# 1365        1365                            Guyana  2005      7.0144
# 2596        2596                             Italy  2006         NaN
# 1657        1657                         Nicaragua  1997   1083.5230
# 1545        1545  Lao People's Democratic Republic  2005    279.6460
# 2641        2641                         Lithuania  1991         NaN
# 3140        3140                    United Kingdom  2010         NaN
# 2224        2224                          Bulgaria  1994         NaN
#
#          Exports  Domestic_consumption  Gross_opening_stocks      Imports  \
# 1802    7.429435                  30.0                 1.000          NaN
# ...

# %%
df.to_csv("../data/coffee-location-imports(tonnes).csv", index=False)
